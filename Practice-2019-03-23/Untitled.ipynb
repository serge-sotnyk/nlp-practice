# %%
import os

md_dir = os.path.join(os.getcwd(), 'mds')

md_filenames = [os.path.join(os.getcwd(), 'mds', filename) for filename in os.listdir(md_dir)]
print(md_filenames)
# Out:
# ['d:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\0xInfection-Awesome-WAF-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\1N3-IntruderPayloads-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\2B5-ia-3B5-master-module3-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\6174-ppurl-master-data-112.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\6174-ppurl-master-data-13.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\6174-ppurl-master-data-154.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\6174-ppurl-master-data-43.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\6174-ppurl-master-data-53.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\6174-ppurl-master-data-64.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\6174-ppurl-master-data-81.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\6174-ppurl-master-data-90.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\aantron-markup.ml-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\abdulfatir-prototypical-networks-tensorflow-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\abudaan-push-notification-server-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\Academany-awesome-fabacademy-master-contributing.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\Accela-Inc-accela-open311-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\accso-java9-jigsaw-examples-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\acemod-ACE3-master-addons-medical_ai-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\acemod-ACE3-master-addons-microdagr-readme.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\acemod-ACE3-master-addons-rearm-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\acrbling-CIS320-Project-Distribution-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\adashofdata-nlp-in-python-tutorial-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\adilmoujahid-Blog-master-content-2016-data-viz-talkingdata.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\adimichele-poetry-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\adobe-NLP-Cube-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\aframevr-awesome-aframe-master-ARCHIVE.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\afshinrahimi-jobdescription2jobtitle-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\agentsoz-jill-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\ageron-handson-ml-master-datasets-lifesat-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\ageron-handson-ml-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\Ai-Thinker-Open-GPRS_C_SDK-master-README_EN.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\aimacode-aima-lisp-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\airalcorn2-Hangouts-NLP-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\ajinkyakulkarni14-How-I-Extracted-TED-talks-for-parallel-Corpus--master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\ajstarks-deck-master-cmd-decksh-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\akirak-prism-emacs-lisp-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\alekseyzimin-masurca-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\alfredfrancis-ai-chatbot-framework-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\Alhadis-language-emacs-lisp-master-CHANGELOG.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\Alhadis-language-emacs-lisp-master-README.md', 'd:\\git-nlp\\nlp-practice\\Practice-2019-03-23\\mds\\alibaba-ai-mat ...

# %%
from collections import namedtuple

LineStat = namedtuple('LineStat', 'source cleaned line_num total_lines_in_text is_header')

# %%
lines = []

for f in md_filenames:
    with open(f, 'rt', encoding='utf-8') as f:
        file_lines = f.read().splitlines()
    for i, line in enumerate(file_lines):
        source = line.strip()
        if source=='':
            continue
        cleaned = source
        is_header = False
        if line.startswith('# ') or line.startswith('## ') or line.startswith('### '):
            splitted_header = source.split(' ', 1)
            if len(splitted_header)<2:
                continue
            cleaned = splitted_header[1]
            cleaned = cleaned.strip()
            is_header = True
        line_stat = LineStat(source=source, cleaned=cleaned, line_num=i, 
                             total_lines_in_text=len(file_lines), is_header=is_header)
        lines.append(line_stat)
                
 
print(len(lines))
# Out:
# 208846

# %%
print('\n'.join([str(l) for l in lines[:10]]))
# Out:
# LineStat(source='# Awesome WAF [![Awesome](https://cdn.rawgit.com/sindresorhus/awesome/d7305f38d29fed78fa85652e3a63e154dd8e8829/media/badge.svg "Awesome")](https://github.com/0xinfection/awesome-waf)', cleaned='Awesome WAF [![Awesome](https://cdn.rawgit.com/sindresorhus/awesome/d7305f38d29fed78fa85652e3a63e154dd8e8829/media/badge.svg "Awesome")](https://github.com/0xinfection/awesome-waf)', line_num=0, total_lines_in_text=2855, is_header=True)
# LineStat(source='> A curated list of awesome WAF stuff. 🔥', cleaned='> A curated list of awesome WAF stuff. 🔥', line_num=1, total_lines_in_text=2855, is_header=False)
# LineStat(source='>', cleaned='>', line_num=2, total_lines_in_text=2855, is_header=False)
# LineStat(source='> __Foreword:__ This was originally my own collection on WAFs. I am open-sourcing it in the hope that it will be useful for pentesters and researchers out there. You might want to keep this repo on a watch, since it will be updated regularly. "The community just learns from each other." __#SharingisCaring__', cleaned='> __Foreword:__ This was originally my own collection on WAFs. I am open-sourcing it in the hope that it will be useful for pentesters and researchers out there. You might want to keep this repo on a watch, since it will be updated regularly. "The community just learns from each other." __#SharingisCaring__', line_num=3, total_lines_in_text=2855, is_header=False)
# LineStat(source="![Main Logo](images/how-wafs-work.png 'How wafs work')", cleaned="![Main Logo](images/how-wafs-work.png 'How wafs work')", line_num=5, total_lines_in_text=2855, is_header=False)
# LineStat(source='__A Concise Definition:__ A web application firewall is a security policy enforcement point positioned between a web application and the client endpoint. This functionality can be implemented in software or hardware, running in an appliance device, or in a typical server running a common operating system. It may be a stand-alone device or integrated into other network components. *(Source: [PCI DSS IS 6.6](https://www.pcisecuritystandards.org/documents/information_supplement_6.6.pdf))*', cleaned='__A Concise Definition:__ A web application firewall is a security policy enforcement point positioned between a web application and the client endpoint. This functionality can be implemented in software or hardware, running in an appliance device, or in a typical server running a common operating system. It may be a stand-alone device or integrated into other network components. *(Source: [PCI DSS IS 6.6](https://www.pcisecuritystandards.org/documents/information_supplement_6.6.pdf))*', line_num=7, total_lines_in_text=2855, is_header=False)
# LineStat(source='Feel free to [contribute](CONTRIBUTING.md).', cleaned='Feel free to [contribute](CONTRIBUTING.md).', line_num=9, total_lines_in_text=2855, is_header=False)
# LineStat(source='### Contents:', cleaned='Contents:', line_num=11, total_lines_in_text=2855, is_header=True)
# LineStat(source='- [Introduction](#introduction)', cleaned='- [Introduction](#introduction)', line_num=12, total_lines_in_text=2855, is_header=False)
# LineStat(source='- [How WAFs Work](#how-wafs-work)', cleaned='- [How WAFs Work](#how-wafs-work)', line_num=13, total_lines_in_text=2855, is_header=False)

# %%
print(sum(l.source.startswith('### ') for l in lines))
# Out:
# 5012

# %%
print(sum(l.is_header for l in lines))
# Out:
# 12556

# %%
# divide to learn and test set

from random import shuffle

shuffle(lines)
threshold = int(len(lines) * 0.7)
lines_learn = lines[:threshold]
lines_test = lines[threshold:]

print(f"Total lines: {len(lines)}, learn set: {len(lines_learn)}, lines_test: {len(lines_test)}")
# Out:
# Total lines: 208846, learn set: 146192, lines_test: 62654

# %%
import csv
csv.field_size_limit(1000000)

def save_as_csv(filename, data):
    with open(filename, 'wt', encoding='utf-8', newline='') as f:
        fieldnames = LineStat._fields
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows([r._asdict() for r in data])

# %%
print(LineStat._fields)

save_as_csv('learn.csv', lines_learn)
save_as_csv('test.csv', lines_test)
# Out:
# ('source', 'cleaned', 'line_num', 'total_lines_in_text', 'is_header')

# %%
def naive_is_header(line: LineStat):
    return False

# %%
def short_is_header(line: LineStat):
    return True if len(line.cleaned)<32 else False

# %%
def check_measures(classifier):
    tp, tn, fp, fn = 0, 0, 0, 0
    for l in lines:
        l_wo_res = LineStat(source='', cleaned=l.cleaned, line_num=l.line_num, is_header=False)
        res = classifier(l_wo_res)
        if res:
            if l.is_header:
                tp += 1
            else:
                fp += 1
                print(l.source)
        else:
            if l.is_header:
                fn += 1
            else:
                tn += 1
    print(f"TP={tp}, TN={tn}, FP={fp}, FN={fn}")
    prec = tp / (tp+fp+1e-6)
    recall = tp / (tp+fn+1e-6)
    f1 = 2 * prec * recall /(prec + recall+1e-6)
    print(f"Precision={prec}, recall={recall}, F1={f1}")

# %%
check_measures(naive_is_header)
# Out:
# TP=0, TN=201302, FP=0, FN=7546
# Precision=0.0, recall=0.0, F1=0.0

# %%
check_measures(short_is_header)
# Out:
# TP=5590, TN=122296, FP=79006, FN=1956
# Precision=0.06607877440935649, recall=0.7407898223243056, F1=0.12133431164657707

# %%
bad_chars = set('#=./<>|(){}:[];')
def rules_classifier(line: LineStat):
    text: str = line.cleaned
    numbers = sum(c.isdigit() for c in text)
    if numbers*2>len(text):
        return False
    if not text[0].isalnum():
        return False
    if text[0].isalnum() and text[0].islower():
        return False
    if any((c in bad_chars) for c in text):
        return False
    if len(text)>120:
        return False
    if line.line_num<2:
        return True
    if len(text)<32:
        return True
    if text.istitle():
        return True
    
    return False

# %%
check_measures(rules_classifier)
# Out:
# 360 Firewall
# AlertLogic Firewall
# Aliyundun Firewall
# Anquanbao WAF
# Anyu Firewall
# Approach Firewall
# Armor Defense
# Baidu Yunjiasu
# Barikode Firewall
# Barracuda WAF
# Better WP Security
# BitNinja Firewall
# Bluedon IST
# BinarySec WAF
# BlockDos
# CDN NS Application Gateway
# ChinaCache Firewall
# Chuangyu WAF
# Cisco ACE XML Gateway
# Cloudbric Firewall
# Cloudflare
# Comodo Firewall
# Deny-All Firewall
# Distil Firewall
# DoSArrest Internet Security
# DynamicWeb Injection Check
# FortiWeb Firewall
# GoDaddy Firewall
# GreyWizard Firewall
# HyperGuard Firewall
# IBM DataPower
# ISAServer
# Janusec Application Gateway
# Jiasule Firewall
# KnownSec Firewall
# LiteSpeed Firewall
# MissionControl WAF
# NewDefend Firewall
# NSFocus Firewall
# Palo Alto Firewall
# PerimeterX Firewall
# Profense Firewall
# Radware Appwall
# Reblaze Firewall
# Sabre Firewall
# Safe3 Firewall
# SafeDog Firewall
# Secure Entry Firewall
# Shadow Daemon WAF
# ShieldSecurity
# SiteGround Firewall
# SiteLock TrueShield
# Sophos UTM Firewall
# SquareSpace Firewall
# Sucuri CloudProxy
# Tencent Cloud WAF
# USP Secure Entry
# Varnish Cache Firewall
# VirusDie Firewall
# WatchGuard IPS
# WebARX Firewall
# West263 Firewall
# WTS Firewall
# XLabs Security WAF
# Xuanwudun WAF
# Yundun Firewall
# Yunsuo Firewall
# ZenEdge Firewall
# POST Type Query
# GET Type Query
# Read Arbitrary File
# Delete Arbitrary File
# Turn off Proface Machine
# Add a proxy
# Company
# First Last
# Password123$
# INJECTX
# INJECTX%0a%0d%00
# Artificial Intelligence project
# This prints
# CREATE DATABASE
# CREATE TABLE
# Thank you for your suggestions!
# JSON, XML
# No changes necessary
# No changes necessary
# R Statistical Analysis Project
# Earthquake_30Days@proj4string
# Introduction
# Pre-trained word vectors
# Job Title and Description
# Contact
# Moving disc 1 from pin 2 to 1
# Moving disc 3 from pin 0 to 2
# Moving disc 1 from pin 1 to 0
# Moving disc 2 from pin 1 to 2
# Moving disc 1 from pin 0 to 2
# GoalA
# PlanA       PlanD
# GoalB   GoalC
# PlanB   PlanC
# Jill Cognitive Agents Project
# Machine Learning Notebooks
# Hangouts-NLP
# Ajinkya Kulkarni
# Contact
# Make a file
# Show a colored legend
# DATA
# END
# PARAMETERS
# END
# FILE	CONTAINS
# For example
# Change Log
# Emacs Lisp Support
# Commands
# ChildDocTransformer
# Cousin Queries
# Using Span Representations in AllenNLP
# Usage
# Changelog
# Rong 2014
# Bojanowski, Grave, Joulin, Mikolov 2016
# Dai, Le 2015
# Luong, Sutskever, Le, Vinyals, Zaremba 2014
# Choi, Cho, Bengio 2016
# Serban, Sordoni, Lowe, Charlin, Pineau, Courville, Bengio 2016
# Have fun!
# Most tags look like this
# The Csound wizard
# JSON-object
# JSON refresher
# The JSON is
# An example
# UI primitives
# UI-groups
# UI-parameters
# Redefining the defaults
# Csound player
# The following
# We implement a
# Thrift Common Lisp Library
# License
# Using Thrift with Common Lisp
# Building
# It depends on the systems
# Implement the Service
# Translate the Thrift IDL
# Run a Server for the Service
# Issues
# Project Gutenberg
# Copyright 2018 Allison Parrish
# Out-of-the-box framework for NodeJS Microservices
# BURNT NORTON
# BURNT NORTON
# Time present and time past
# Time present and time past
# Asif Sharif
# MIT
# Thanks everyone!
# EOF
# Open the following file
# 3,
# See you soon, John!
# List active address spaces
# NETVSSI   -
# NETVIEW   -
# NETVSAM   -
# RACF      -  START2
# JES2      -
# DLF       -
# RRS       -
# VLF       -
# LLA       -
# CICSTS32  -  START2
# RMF       -  START2
# NET       -  START2
# RMFGAT    -  START2
# TCPIP     -  TCPIP
# TSO       -  START1
# PORTMAP   -  START2
# ZERO     -  ZERO
# IBMUSER   -  IBMUSER
# FTPD1     -  FTPD
# INETD4    -  OMVSKERN
# Got ASID 80 for IBMUSER
# Got ASID 38 for current session
# Local ACEE at  008FC6F0
# Command
# Arguments
# Admin Account Arguments
# Advanced Arguments
# Auto Storage Arguments
# Azure Storage Mount Arguments
# File Server Mount Arguments
# Nodes Arguments
# Setup Task Arguments
# Virtual Network Arguments
# Global Arguments
# Examples
# Command
# Arguments
# Global Arguments
# Examples
# Group
# Group
# Command
# Arguments
# Azure Storage Mount Arguments
# File Server Mount Arguments
# Global Arguments
# Examples
# For example,
# Command
# Arguments
# Global Arguments
# Examples
# Command
# Arguments
# Global Arguments
# Examples
# Command
# Arguments
# Global Arguments
# Examples
# For example,
# Command
# Arguments
# Admin Account Arguments
# Advanced Arguments
# Storage Disks Arguments
# Virtual Network Arguments
# Global Arguments
# Examples
# For example,
# SELECT TOP 100 *
# SELECT TOP 20 *
# ORDER BY EId DESC
# Blueprint\\Deployment\\Reports\\
# July 2018
# Drew Conway
# Can you describe this dataset?
# True
# Model evaluation
# MIT License
# SOFTWARE
# Through this series of projects
# Write scripts that write poems
# Rhino 3D model, 3D renderings,
# Create this repository in the
# This work is licensed under a
# ONE MORE LINE?
# Gilles Adda and
# Juan Benjumea and
# Laurent Besacier and
# Lori Lamel and
# Annie Rialland and
# Why another template engine?
# Install-Package SuperXml
# Hello John
# Hello Maria
# Hello Mark
# Hello Edit
# Hello Susan
# Compiled
# Input XML
# Compiled
# The Apache OFBiz™ Project
# Java开源网店系统 SHOP++
# Java商场系统 JEShop
# 网上商店系统 JAVASHOP
# 多用户Java商城系统 LegendShop
# Java商城网店软件 TurboShop
# 电子商务平台 faceCart
# 宠物商店 PetStore
# Web销售管理系统 Shopizer
# 在线商城系统 jshoper（ostocy-jshop）
# Web应用框架 Pulse-java
# Kgmall 金刚多用户商城系统 kgMall
# Java 电子商务软件 Broadleaf
# 电子商务应用程序 Smilehouse Workspace
# Getting Started
# License
# Hinab auf die Graber in Lage
# GNU GENERAL PUBLIC LICENSE
# Version 3, 29 June 2007
# END OF TERMS AND CONDITIONS
# Board width
# Board height
# What's your name? Boro
# Nice to meet you, Boro
# What is your name? Hello
# What is your name? Hi
# Hello Hi
# What is your name? Hello
# What is your name? Hi
# Hello Hi
# What is your name? Hello
# What is your name? Hi
# Hello Hi
# About
# Setup
# Usage
# Current Supported Events
# Mark Thuckerbot
# Initial release
# NOT APPLICABLE
# NOT APPLICABLE
# Bar Graph
# Grouped Bar Graph
# CxMediaCounter
# Introduction
# Available types
# Where `VisitorType` is
# Notes linked overview
# Installation
# To use it
# Awesome CatBoost
# Show threads On
# Linking successful
# Objects erasure encoded by Ceph
# 世事如收去，
# 相逢未自知。
# 一些简单的高频分析
# Acronym   Name                              Type         Application
# Age range    Count
# 0--5            36
# 6--10           19
# 11--15          18
# 16--20          99
# 21--25         139
# 26--30         121
# Age range    Count
# 31--35          76
# 36--40          74
# 41--45          54
# 46--50          50
# 51--55          26
# 56--60          22
# Age range    Count
# 61--65          16
# 66--70           3
# 71--75           3
# Navi Corpus
# Directory of bosh releases, with meta-data
# 7 name of failed test
# Polish, Chinese, French, Russian, Italian, Dutch
# Grady Ward
# Arcata, CA  95521-4884
# Welcome to the \t the jungle\n
# I can stay \t here all night\n
# The CoNaLa data was mined using a scalable, language-agnostic approach for mining parallel
# GPL-2
# 接下来解剖这段代码，首先是
# 这些策略执行是有顺序的，从前往后执行。
# 下面，可以以SortExec为例讲解codeden过程
# 创建sorter
# 下面，就是codegen的过程
# 其中cache类型是localcache的定义如下：
# Contents
# The San Francisco Chronicle,
# Big in Greater China? Updates
# Gambling vs Investing
# And, of course, the kitties
# Currently
# Public Kitty Datasets & More
# Description
# Who should join?
# What won't be covered
# Prerequisites for day 1
# Details
# Conclusion
# Instructor Bios
# License
# Installing datasus
# MagicCircles
# What is Magic Circles?
# Because I DON'T KNOW!
# In julia,
# Functions can take functions
# Can be accomplished using
# Much better!
# Basic loops
# License
# Datasets of Annotated Semantic Relationships
# 1,
# 2,
# 3,
# 1,
# 2,
# MessagePack binary JSON format
# FjarrgljfurCanyonIceland
# NewTownEdinburghScotland
# SunriseInBryceCanyonUT
# KariegaGameReserveSouthAfrica
# ValleDeLaLunaChile
# 20% Annotated lab notebooks
# 25% Midterm
# 35% Final Exam
# TemplaVoila migration to Fluidtemplate and Grid Element
# Company
# First Last
# Password123$
# INJECTX
# About to remove linode
# Successfully removed linode
# We'll start by taking care of
# TRAIN_PATH,
# VALID_PATH,
# TEST_PATH,
# PREDICT_PATH,
# Parameters
# Parameters
# Parameters
# Returns
# Parameters
# Returns
# Average loss
# The translation output
# Pre-trained language
# While feature-based
# Then
# In this
# English Wikipedia dataset in
# Let's first take
# Let's load the
# Now that we have loaded
# The first line of
# For our task, we are
# We will use
# Pre-training of deep
# Proceedings of
# To demonstrate how to use pre-
# We can also create
# In this example,
# The *window* size is usually
# To obtain good
# The *final* embedding
# Possible SubwordFunctions
# Above
# For
# One for the
# For center words, subwords are
# It can be used
# In
# Let's instantiate and
# In the Word Similarity and
# HorizonUIPlugin
# System Requirements
# Installation Guide
# Technical Details
# Contact and Support
# Version History
# 0	Private	11th	Never-married
# Sentiment   SentimentText
# 0	Private	11th	Never-married
# 0	Private	11th	Never-married
# 0	Private	11th	Never-married
# Sentiment   SentimentText
# Core
# Suggested approach -
# Validate XML
# LSTM Poetry
# You said I was falling apart
# I wish I were you
# I wanted you to know how I feel
# I could have settled it all
# I can't stop this way
# The stars are singing the songs
# I need you to stay away
# We are the spirit of the beast
# The way that we started love
# Let the sun shine on your face
# We will hear you fall apart
# MIT
# 文本样式用来设置文字的外观，以下是常用文本样式属性，更详细的信息请参考API文档。
# 设置字体的属性是 `fontFamily`
# 示例代码如下：
# 编译并运行，效果如下：
# 示例代码如下：
# 编译并运行，效果如下：
# 具体代码如下：
# 编译并运行，效果如下：
# 设置加粗的属性为 `bold`
# 设置斜体的属性为 `italic`
# 具体代码如下：
# 编译并运行，效果如下：
# 图1 一段样式丰富的文本
# Egret 提供两种实现方案。
# 给一段文字定义红色、字号30样式的代码如下：
# 实现图1中效果的代码如下：
# 将得到与JSON方式设置样式类似的结果。
# 编译并运行，效果如下：
# 文本的布局分为横向和纵向两种。
# 横向布局可以设置文字居左，水平居中，居右。
# 纵向布局可以设置文字居顶，垂直居中，居底。
# 编译并运行，效果如下：
# 编译并运行，效果如下：
# 在使用横向布局与纵向布局时，两者并不冲突。
# 编译并运行，效果如下：
# 编译并运行，效果如下：
# 点击上面的有链接的文字效果如下：
# OR
# OR MANUALLY
# Poetry
# Welcome!
# Gold-Standard Sentence Splitting Corpus
# The published PDF
# Julia$ julia
# Welcome to Adventure Game Studio! This new Windows Help version of the
# Copyright and terms of use
# Introduction
# Welcome to AGS!
# System Requirements
# The run-time engine
# The demo game
# Graphics driver selection
# Run-time engine setup
# Game language
# Vertical sync
# Use 85 Hz display
# Smooth scaled sprites
# Digital sound
# MIDI music
# Use voice pack is available
# Auto lock to window
# Mouse speed
# Sprite cache max size
# Custom game saves path
# Tutorial
# Starting off
# Setting up the game
# Loop 1 - walking left
# Loop 2 - walking right
# EGO, I would write
# For the standard modes,
# Advanced room features
# Other Features
# Music and sound
# Editing the GUIs
# Distributing your game
# Backing up your game
# The text parser
# Translations
# Global variables
# Custom Properties
# Plugins
# Lip sync
# New Game templates
# Debugging features
# Auto-number speech files
# Integration with Windows
# Source Control integration
# Scripting
# Scripting tutorial part 1
# Scripting tutorial part 2
# Pointers in AGS
# The script header
# String formatting
# Multiple Scripts
# Understanding blocking scripts
# Dynamic Arrays
# Extender functions
# Game variables
# WHAT TYPE Description
# 1    1   Look at hotspot
# 1    2   Interact with hotspot
# 1    4   Talk to hotspot
# 1    7   Pick up hotspot
# 2    0   Look at object
# 2    1   Interact with object
# 2    2   Talk to object
# 2    5   Pick up object
# 3    0   Look at character
# 3    2   Speak to character
# 3    5   Pick up character
# 4    2   Interact with nothing
# 4    4   Talk to nothing
# 5    0   Look at inventory
# 5    2   Speak to inventory
# Custom dialog options rendering
# Built-in enumerated types
# Script language keywords
# Operator  Description              Example
# BakeCake,
# DoLaundry
# Dialog functions and properties
# FontType font, Alignment,
# File functions and properties
# GUI functions and properties
# ILBRK
# ILBRK
# ILBRK
# ILBRK
# GUI Slider properties
# ILBRK
# ILBRK
# Maths functions and properties
# Mouse functions and properties
# Multimedia functions
# 0  player can't skip animation
# Object functions and properties
# Palette functions
# Parser functions
# Region functions and properties
# Player walks off region
# Room functions
# Screen functions
# 0  normal
# Speech functions and properties
# ILBRK*
# The accepted values are
# ILBRK*
# The accepted values are
# String functions
# System functions and properties
# SCUMM\_VERBCOIN\_GUI functions
# Reference
# Event Types
# Player stands on hotspot
# Look at hotspot
# Interact with hotspot
# Use inventory on hotspot
# Speak to hotspot
# Any click on hotspot
# Mouse moves over hotspot
# Look at object
# Interact with object
# Speak to object
# Use inventory on object
# Walk off left
# Walk off right
# Walk off bottom
# Walk off top
# First time enters room
# Repeatedly execute
# Player leaves room
# Look at inventory
# Interact with inventory
# Speak to inventory
# Use inventory on inv
# Other click on inventory
# Look at character
# Interact with character
# Speak to character
# Use inventory on character
# Any click on character
# While player stands on region
# Player walks onto region
# Player walks off region
# System limits
# 40  objects per room
# 300  inventory items
# 30000  imported sprites
# 500  dialog topics
# 30  options per dialog topic
# 20  screen overlays at a time
# 5  background frames per room
# 20  mouse cursors
# 8  audio channels
# 30  fonts
# Keyboard Shortcuts
# F1       Help
# F2       Game Statistics
# F3       Find Next
# Ctrl+F4  Close tab
# F5       Run with Debugger
# Ctrl+F5  Run without Debugger
# F7       Build EXE
# F9       Toggle Breakpoint
# F11      Step Into
# Ctrl+A   Select All
# Ctrl+B   Match Brace
# Ctrl+C   Copy
# Ctrl+D   Duplicate line to next
# Ctrl+E   Replace
# Ctrl+F   Find
# Ctrl+L   Open Game
# Ctrl+Q   Quit
# Ctrl+R   Save Room
# Ctrl+S   Save Game
# Ctrl+V   Paste
# Ctrl+W   Close Tab
# Ctrl+X   Cut
# Ctrl+Y   Redo
# Ctrl+Z   Undo
# Ctrl+Space      Show Autocomplete
# Ctrl+Tab        Next tab
# Ctrl+Shift+Tab  Previous tab
# ASCII code table
# 403       Left shift
# 404       Right shift
# 405       Left ctrl
# 406       Right ctrl
# 407       Alt
# Frequently Asked Questions
# English?**
# Have fun, ILBRK CJ
# Music folders?**
# Anonymous usage information
# Contacting the developers
# Credits
# Benjamin Penney
# Benoit Pierre
# Bernhard Rosenkraenzer
# Cristian Morales Vega
# Edward Rudd
# Ferdinand Thiessen
# Francesco Ariis
# Gilad Shaham
# Ivan Mogilko
# Janet Gilbert
# Jochen Schleu
# Joe Lee
# Michael Rittenhouse
# Morgan Willcock
# Nick Sonneveld
# Ori Avtalion
# Paul Wilkinson
# Per Olav Flaten
# Piotr Wieczorek
# Scott Baker
# Shane Stevens
# Stefano Collavini
# Steve McCrea
# Steven Poulton
# Sunit Das
# Tobias Hansen
# Tom Vandepoele
# Tzach Shabtay
# Parameters
# Description
# Some Features
# Examples
# 0      IMAGE_HDU
# 1      BINARY_TBL      mytable
# Installation
# Requirements
# Tests
# TODO
# Notes on cfitsio bundling
# Note on array ordering
# Exercism provides exercises and feedback but can be difficult to jump
# Paul Nathan
# Start up your Lisp implementation in the directory of the exercise you
# Exercism exercises in Lisp
# Please be familiar with the
# Feel free to file any issues at
# Contributor License
# Note that the
# Copyright 2014-present Facebook
# ASDF Best Practices
# Some systems offer operations
# Thanks for your suggestions!
# Install fastai and you're off!
# 作者 Roberto Ierusalimschy, Luiz Henrique de Figueiredo, Waldemar Celes
# 本章描述Lua的基本概念。
# 加载时注入的_ENV是一个table，它表示环境变量。
# 你可以通过getmetatable函数来获取某值的元表。
# 对于一元操作符（取反、取长度和位非），元方法在被调用时会传入一个与首参数一致的第二个参数。这个多余的第二个参数只是为了Lua的实现方便。函数的实现代码中应该不能依赖于第二个参数，因为它可能在未来版本被移除。
# 下面是一个协程的示例：
# 上面的代码运行后会输出如下内容：
# 这一章描述了Lua的词法、语法和语义。
# 本章介绍Lua的文本。
# 下面这些关键词被语言保留：
# 字面串中的每个不被上述规则影响的字节都呈现为本身。 然而，Lua 是用文本模式打开源文件解析的， 一些系统的文件操作函数对某些控制字符的处理可能有问题。 因此，对于非文本数据，用引号括起来并显式按转义符规则来表述更安全。
# 下面都是一样的：
# 3   345   0xff   0xBEBADA
# 任何变量，在首次assignment之前的值是nil。
# 方括号用来index一个table。
# 这个过程的具体意义可以通过改变metatables来改变。
# 一个block是一系列statement，它们顺序执行。
# 从语法上说，可能有如下两种解释：
# 可以使用do end显式地为一个块定界：
# Lua支持多重赋值，其语法定义为等号左边有一个变量列表，而右边有一个表达式列表：
# Lua还有2种形式的for语句。
# 数值类型的for循环的语法：
# 就那样执行，比如：
# 注意一下几点：
# 你可以使用break或者goto来退出一个for-loop。
# A for statement like
# 记住下面这个语义即可：
# 注意以下几点：
# 在这个情况下，所有的返回values都会被丢弃。
# Lua有下面这些基本表达式：
# 一些多varlist的规则：
# 这里有一些例子：
# Lua支持如下的数学运算符：
# Lua支持如下的关系操作：
# 关系操作的结果总是false或者true。
# 这里注意lua对某些数值的处理比如：
# Lua 中操作符的优先级写在下表中，从低到高优先级排序：
# 等价于
# 有个语法糖，
# 即：
# 两个是一样的。用它方便找“对象”。
# 这个形式被用来调用“对象”的成员函数（method）。
# 即：
# Lua 中的函数调用的语法如下：
# 这样的形式
# 参数的语法如下：
# 函数定义的语法如下：
# 另外定义了一些语法糖简化函数定义的写法：
# 该语句
# 被转译成
# 该语句
# 被转译成
# 该语句
# 被转译成
# 而不是
# 形参被看作是一些局部变量， 它们将由实参的值来初始化：
# 我们先做如下定义，然后再来看一个例子：
# 下面看看实参到形参数以及可变长参数的映射关系：
# CALL            PARAMETERS
# 是这样一种写法的语法糖
# 除了定义为local的变量，其它变量都是全局的。
# API中接受索引的函数均只接受有效索引或者可接受索引。
# 可接受索引避免了在查询栈元素时对栈顶的额外检查。比如，一个C函数可以查询其第三个参数但不需要事先检查它是否存在，即，不需要检查3是否是一个有效索引。
# 下面的函数会做一个说明：
# A pattern item can be
# The available formats are
# React-designer
# SizePanel,
# TextPanel,
# StylePanel,
# ArrangePanel
# Make blue
# Make Yellow
# Contributor License
# Note that the
# Copyright 2014-present Facebook
# 注：需安装 npm install fetpl express
# This is index
# This is a
# This is b
# Perlito5 Java backend
# Requirements
# Build using make
# Perlito5-Java work-in-progress
# Regex differences
# Eval-string
# Limitations
# Perlito5-Java extensions
# Using typed variables
# Z
# Thread safety
# Perlito5 Java development tools
# Perlito5 Java backend TODO list
# CPAN distribution
# Java distribution
# Precompile modules
# BEGIN blocks
# JVM and Java compiler related
# Value types
# 3,
# Slices
# Variables
# Overflow from long to double
# Tail-call
# DOES
# Not an ARRAY at -e
# Regex
# Storable
# Memory management
# Threads
# CLONE, CLONE_SKIP
# Optimizations
# Modules
# Attributes
# The Git repository for
# What does that mean?
# SMPTE ST 2110-20 dissector
# Command Line App
# A Dummy Staff
# Configuring Lunch Roulete
# Gut Testing Lunch Roulette
# CSV Output
# Learn More & Math
# Thank you for being involved! 😍
# Generating the corpus
# Corpus format
# Other files in this repo
# Representing Kekule Cells in Stable Molecules
# 88 Colin P Kelly Jr St
# Prague, June 30, 2015
# Infringement Notice
# Thank you!
# Kind regards,
# 88 Colin P Kelly Jr St
# Prague, September 21, 2015
# Infringement Notice
# Thank you!
# 701 First Ave
# Sunnyvale, CA 94089
# Who owns the zebra?
# Playing Atari games
# You will also learn basics of
# Did it find any bugs so far?
# Running 4 workers
# Did you see the differentce?
# What is the bug?
# Did it crash? How?
# When combined with
# Thinking about ASSERTS
# Koan "ASSERT-TRUE"
# CLASSES  PROBABILITIES
# Examples
# Setup
# To Use
# Rename a data object\n"
# YIELD result
# RETURN result
# YIELD result
# RETURN result
# YIELD result RETURN result
# YIELD result
# RETURN result
# RETURN result
# YIELD result return result
# RETURN result
# And retrieve it with
# YIELD result
# RETURN result
# GraphAware NLP Using StanfordNLP
# Getting the Software
# Introduction and How-To
# RETURN n, result
# The O
# Apollo  MISSION
# 1   MISSION
# NASA    O
# April   O
# 24  O
# 1967    O
# RMI client
# Usage
# Where params may contain
# Configuration
# String num1
# String num2
# String result
# Testing
# Next is the test
# Tool Support
# Usage
# Configuration
# String num1
# String num2
# String result
# Testing
# Next is the test
# Tool Support
# Motion AI Ruby SDK
# Project Repo
# Motion AI Docs
# Smart Mirror with a smart AI 🤖
# Verify it starts
# Install ffmpeg
# Activate the virual evironment
# Install openCV with
# Check the version with
# Check that the files are there
# Start the app
# 另外还提供了更标准的语法，特性。
# I'm a multi-line
# 内置的属性，模块文档
# SCHED_FILE
# PARAM_FILE
# Experiment begins!
# Experiment ends!
# G-EDF, P-EDF, C-EDF
# Managed Data Structures
# 4000 lines of modern poetry
# These are the materials for my workshop on creating interactive data visualizations with D3!
# Coming Soon!
# The code assign to a parameter
# Class Account
# Vector vector
# Mechanics
# Person person
# Ectyper
# Synopsis
# Description
# Defaults to center
# Defaults to center
# Defaults to "over"
# Defaults to center
# Defaults to center
# Defaults to "over"
# Examples
# License
# Contact
# Documentation
# License
# Reader接口的定义如下：
# 官方文档中关于该接口方法的说明：
# 也就是说，当Read方法返回错误时，不代表没有读取到任何数据。调用者应该处理返回的任何数据，之后才处理可能的错误。
# 下面，我们通过具体例子来谈谈该接口的用法。
# Writer接口的定义如下：
# 官方文档中关于该接口方法的说明：
# 除此之外，io包本身也有这两个接口的实现类型。如：
# 实现了Writer的类型：PipeWriter
# 官方文档中关于该接口方法的说明：
# 可见，ReaderAt接口使得可以从指定偏移量处开始读取数据。
# 简单示例代码如下：
# 运行结果：
# 语言, 6
# 官方文档中关于该接口方法的说明：
# 我们可以通过该接口将数据写入数据流的特定偏移量之后。
# Golang中文社区——Go语言学习园地
# 分析：
# 官方文档中关于该接口方法的说明：
# 下面的例子简单的实现将文件中的数据全部读取（显示在标准输出）：
# 代码实现如下：
# 方法１：
# 方法２：
# 官方文档中关于该接口方法的说明：
# 这里只提供简单的一个示例代码：将一段文本输出到标准输出
# 接口定义如下：
# 官方文档中关于该接口方法的说明：
# 运行结果：
# 园
# 接口定义如下：
# 实际编程中，经常将Close方法的调用放在defer语句中。
# 初学者容易写出这样的代码：
# ByteScanner接口的定义如下：
# ByteReader
# 和
# Reader
# Writer
# 这是Reader接口和Writer接口的简单组合（内嵌）。
# 从名称我们可以猜到，该类型读取数据流中部分数据。看一下
# 的文档说明就知道了：
# 由于该类型所支持的操作，前面都有介绍，因此提供示例代码了。
# LimitedReader 类型定义如下：
# 文档说明如下：
# 也就是说，最多只能返回 N 字节数据。
# 使用示例如下：
# 运行结果：
# This Is LimitReader
# 可见，通过该类型可以达到 *只允许读取一定长度数据* 的目的。
# PipReader 和 PipWriter 类型
# 其他方法的使用通过例子一起讲解：
# 运行结果：
# Go语言学习园地
# Go语言学习园地
# Go语言学习园地
# 代码分析：
# 函数文档：
# 代码：
# 直接将内容输出（写入Stdout中）。
# 我们甚至可以这么做：
# 函数文档：
# 代码：
# 会输出：
# Go语言
# 函数文档：
# 函数文档：
# 这是为了方便写入string类型提供的函数，函数签名：
# 这两个函数的定义分别是：
# 它们接收多个Reader或Writer，返回一个Reader或Writer。我们可以猜想到这两个函数就是操作多个Reader或Writer就像操作一个。
# 对于这两种类型对应的实现方法（Read和Write方法）的使用，我们通过例子来演示。
# 运行结果：
# 函数签名如下：
# 也就是说，我们通过Reader读取内容后，会自动写入到Writer中去。例子代码如下：
# 输出结果：
# 这种功能的实现其实挺简单，无非是在Read完后执行Write。
# 至此，io所有接口、类型和函数都讲解完成。
# The National Budget
# Sunburst
# Stacked bars
# Getting the data
# Notes
# Description
# Windows 8
# Properties
# Events
# TBD
# TBD
# TBD
# TBD
# TBD
# MIT
# Overview
# Service API
# Example
# URL builder
# Purpose
# Advanced
# Credits
# License
# Initialization & Usage
# Options
# Events
# Methods
# Requirements
# The plugin requires
# Compatibility
# Licensing
# CS 4650 and 7650
# Go to town!
# Examples using Promise
# Copyright Jason Kneen
# 译者在翻译时，使用了一些尚未统一的中文术语译词，统一罗列如下：
# 元表      metatable
# 元方法    metamethod
# 弱表      weak table
# 协程      coroutine
# 闭包      closure
# 注册表    registry
# 让出      yield
# 表        table
# 用户数据   userdata
# 延续点     continuation
# 宿主      host
# 一等公民   first-class
# 语法糖     syntactic sugar
# 序列      sequence
# 异构      heterogeneous
# 终结器     finalizer
# 暂时表     ephemeron table
# 符记      token
# 字面串     literal string
# 代码块     chunk
# 标签      label
# 实例化     instantiated
# 上值      upvalue
# 本章描述了语言的基本概念。
# 表、函数、线程、以及完全用户数据在 `Lua` 中被称为 对象： 变量并不真的 持有 它们的值，而仅保存了对这些对象的 引用。 赋值、参数传递、函数返回，都是针对引用而不是针对值的操作， 这些操作均不会做任何形式的隐式拷贝。
# 被 `_ENV` 用于值的那张表被称为 环境。
# 无论何时出现错误，都会抛出一个携带错误信息的 错误对象 （错误消息）。 `Lua` 本身只会为错误生成字符串类型的错误对象， 但你的程序可以为错误生成任何类型的错误对象， 这就看你的 `Lua` 程序或宿主程序如何处理这些错误对象。
# 对一张表的弱属性的修改仅在下次收集循环才生效。 尤其是当你把表由弱改强，`Lua` 还是有可能在修改生效前回收表内一些项目。
# 只有那些有显式构造过程的对象才会从弱表中移除。 值，例如数字和轻量 C 函数，不受垃圾收集器管辖， 因此不会从弱表中移除 （除非它们的关联项被回收）。 虽然字符串受垃圾回收器管辖， 但它们没有显式的构造过程，所以也不会从弱表中移除。
# 下面的代码展示了一个协程工作的范例：
# 当你运行它，将产生下列输出：
# 这一章描述了 `Lua` 的词法、语法和句法。 换句话说，本章描述哪些符记是有效的， 它们如何被组合起来，这些组合方式有什么含义。
# 下列 关键字 是保留的，不可用于名字：
# 下列字符串是另外一些符记：
# 字面串中的每个不被上述规则影响的字节都呈现为本身。 然而，`Lua` 是用文本模式打开源文件解析的， 一些系统的文件操作函数对某些控制字符的处理可能有问题。 因此，对于非文本数据，用引号括起来并显式按转义符规则来表述更安全。
# 3   345   0xff   0xBEBADA
# 以下为合法的浮点常量：
# 变量是储存值的地方。 Lua 中有三种变量： 全局变量、局部变量和表的域。
# 在变量的首次赋值之前，变量的值均为 `nil`。
# 方括号被用来对表作索引：
# Lua 支持所有与 Pascal 或是 C 类似的常见形式的语句， 这个集合包括赋值，控制结构，函数调用，还有变量声明。
# 语句块是一个语句序列，它们会按次序执行：
# Lua 支持 空语句， 你可以用分号分割语句，也可以以分号开始一个语句块， 或是连着写两个分号：
# 函数调用和赋值语句都可能以一个小括号打头， 这可能让 Lua 的语法产生歧义。 我们来看看下面的代码片断：
# 从语法上说，可能有两种解释方式：
# 一个语句块可以被显式的定界为单条语句：
# 代码块可以被保存在文件中，也可以作为宿主程序内部的一个字符串。 要执行一个代码块， 首先要让 `Lua` 加载 它， 将代码块中的代码预编译成虚拟机中的指令， 而后，`Lua` 用虚拟机解释器来运行编译后的代码。
# 会交换 x 和 y 的值， 及
# 会轮换 x，y，z 的值。
# 标签和没有内容的语句被称为空语句，它们不做任何操作。
# 这等价于代码：
# 注意下面这几点：
# 这样的 `for` 语句
# 它等价于这样一段代码：
# 注意以下几点：
# 为了允许使用函数的副作用， 函数调用可以被作为一个语句执行：
# 这里有一些例子：
# Lua 支持下列数学运算操作符：
# 当操作需要数字时，`Lua` 还会把字符串转换为数字。
# 从字符串到数字的转换过程遵循以下流程： 首先，遵循按 `Lua` 词法分析器的规则分析语法来转换为对应的 整数或浮点数。 （字符串可以有前置或后置的空格以及一个符号。） 然后，结果数字再按前述规则转换为所需要的类型（浮点或整数）。
# 这些操作的结果不是 `false` 就是 `true`。
# Lua 中操作符的优先级写在下表中，从低到高优先级排序：
# 等价于
# 这样的形式
# 参数的语法如下：
# 函数定义的语法如下：
# 另外定义了一些语法糖简化函数定义的写法：
# 该语句
# 被转译成
# 该语句
# 被转译成
# 该语句
# 被转译成
# 而不是
# 形参被看作是一些局部变量， 它们将由实参的值来初始化：
# 我们先做如下定义，然后再来看一个例子：
# 下面看看实参到形参数以及可变长参数的映射关系：
# CALL            PARAMETERS
# 是这样一种写法的语法糖
# Lua 语言有词法作用范围。 变量的作用范围开始于声明它们之后的第一个语句段， 结束于包含这个声明的最内层语句块的最后一个非空语句。 看下面这些例子：
# 允许可接受索引是为了避免对栈顶以外的查询时做额外的检查。 例如，`C` 函数可以直接查询传给它的第三个参数， 而不用先检查是不是有第三个参数， 即不需要检查 3 是不是一个有效索引。
# 下面的函数会做一个说明：
# 对栈顶的两个值（或者一个，比如取反）做一次数学或位操作。 其中，栈顶的那个值是第二个操作数。 它会弹出压入的值，并把结果放在栈顶。 这个函数遵循 Lua 对应的操作符运算规则 （即有可能触发元方法）。
# 调用一个函数。
# 下面的例子中，这行 `Lua` 代码等价于在宿主程序中用 C 代码做一些工作：
# 这里是 `C` 里的代码：
# 该函数不会把 Lua 函数弹出堆栈。
# 控制垃圾收集器。
# 这个函数根据其参数 what 发起几种不同的任务：
# 关于这些选项的细节，参见 collectgarbage 。
# 函数将返回压入值的类型。
# 返回一个 Lua 状态机中关联的内存块指针。 程序可以把这块内存用于任何用途；而 Lua 不会使用它。
# 把全局变量 name 里的值压栈，返回该值的类型。
# 返回压入值的类型。
# 返回压入值的类型。
# 将给定索引处的用户数据所关联的 Lua 值压栈。
# 返回压入值的类型。
# Lua 中的整数类型。
# 当给定索引的值是一个布尔量时，返回 1 ，否则返回 0 。
# 当给定索引的值是一个 C 函数时，返回 1 ，否则返回 0 。
# 当给定索引的值是一个函数（ C 或 Lua 函数均可）时，返回 1 ，否则返回 0 。
# 当给定索引的值是 nil 时，返回 1 ，否则返回 0 。
# 当给定索引无效时，返回 1 ，否则返回 0 。
# 当给定索引的值是一张表时，返回 1 ，否则返回 0 。
# 当给定索引的值是一条线程时，返回 1 ，否则返回 0 。
# 如果给定的协程可以让出，返回 1 ，否则返回 0 。
# 没有显式的函数可以用来关闭或销毁掉一个线程。 线程跟其它 Lua 对象一样是垃圾收集的条目之一。
# 典型的遍历方法是这样的：
# 关于迭代过程中修改被迭代的表的注意事项参见 next 函数。
# Lua 中浮点数的类型。
# 该宏有可能对其参数做多次取值。
# 以保护模式调用一个函数。
# 从栈中弹出 n 个元素。
# 把 b 作为一个布尔量压栈。
# 把一个新的 C 闭包压栈。
# 你不需要为结果分配空间： 其结果是一个 Lua 字符串，由 Lua 来关心其内存分配 （同时通过垃圾收集来释放内存）。
# 将全局环境压栈。
# 把值为 n 的整数压栈。
# 把一个轻量用户数据压栈。
# 返回内部副本的指针。
# 将空值压栈。
# 把一个值为 n 的浮点数压栈。
# 返回内部副本的指针。
# 如果 s 为 NULL，将 nil 压栈并返回 NULL。
# 把 L 表示的线程压栈。 如果这个线程是当前状态机的主线程的话，返回 1 。
# 把栈上给定索引处的元素作一个副本压栈。
# 返回入栈值的类型。
# 返回入栈值的类型。
# 这个函数会将值弹出栈。 赋值是直接的；即不会触发元方法。
# 这个函数会将值弹出栈。 赋值是直接的；即不会触发元方法。
# 在给定线程中启动或延续一条协程 。
# 把指定状态机的分配器函数换成带上用户数据 ud 的 f 。
# 从堆栈上弹出一个值，并将其设为全局变量 name 的新值。
# 把一张表弹出栈，并将其设为给定索引处的值的元表。
# 从栈上弹出一个值并将其设为给定索引处用户数据的关联值。
# 一个不透明的结构， 它指向一条线程并间接（通过该线程）引用了整个 Lua 解释器的状态。 Lua 库是完全可重入的： 它没有任何全局变量。 状态机所有的信息都可以通过这个结构访问到。
# 返回线程 L 的状态。
# 这个函数通常只用于调试信息。
# 交换同一个状态机下不同线程中的值。
# 让出协程（线程）。
# 当一个线程处于未提供延续函数的 C 调用中，调用它会抛出一个错误。 从并非用延续方式（例如：主线程）启动的线程中调用它也会这样。
# Lua 没有内置的调试机制。 但是它提供了一组特殊的函数接口以及 钩子。 这组接口可用于构建出不同的调试器、性能剖析器、 或是其它需要从解释器获取“内部信息”的工具。
# 其它域
# 下面对 lua_Debug 的各个域做一个说明：
# 返回当前的钩子函数。
# 返回当前的钩子计数。
# 返回当前的钩子掩码。
# 返回一个指定的函数或函数调用的信息。
# 如果这个选项和选项 'f' 同时使用， 这张表在函数之后压栈。
# 这个函数出错会返回 0 （例如，what 中有一个无效选项）。
# 从给定活动记录或从一个函数中获取一个局部变量的信息。
# 获取解释器的运行时栈的信息。
# 用于调试的钩子函数类型。
# 当 Lua 运行在一个钩子内部时， 它将屏蔽掉其它对钩子的调用。 也就是说，如果一个钩子函数内再调回 Lua 来执行一个函数或是一个代码块 ， 这个执行操作不会触发任何的钩子。
# 设置一个调试用钩子函数。
# 钩子可以通过设置 mask 为零屏蔽。
# 当索引大于上值的数量时，返回 NULL （什么也不弹出）。
# 这些唯一标识符可用于检测不同的闭包是否共享了相同的上值。 共享同一个上值的 Lua 闭包（即它们指的同一个外部局部变量） 会针对这个上值返回相同的标识。
# 这里我们按字母表次序列出了辅助库中的所有函数和类型。
# 这个函数永远不会返回。
# 字符串缓存 的类型。
# 字符串缓存可以让 C 代码分段构造一个 Lua 字符串。 使用模式如下：
# 首先定义一个类型为 luaL_Buffer 的变量 b。
# 然后调用 luaL_add* 这组函数向其添加字符串片断。
# 如果你预先知道结果串的长度， 你可以这样使用缓存：
# 首先定义一个类型为 luaL_Buffer 的变量 b。
# 接着将字符串复制入这个空间。
# 调用一个元方法。
# 检查函数在 arg 位置是否有任何类型（包括 nil）的参数。
# 检查函数的第 arg 个参数是否是一个 数字，并返回这个数字。
# 这个函数通常用于将字符串映射为 C 枚举量。 （在 Lua 库中做这个转换可以让其使用字符串，而不是数字来做一些选项。）
# 检查调用它的内核是否是创建这个 Lua 状态机的内核。 以及调用它的代码是否使用了相同的 Lua 版本。 同时也检查调用它的内核与创建该 Lua 状态机的内核 是否使用了同一片地址空间。
# 加载并运行指定的文件。 它是用下列宏定义出来：
# 如果没有错误，函数返回假； 有错则返回真。
# 加载并运行指定的字符串。 它是用下列宏定义出来：
# 如果没有错误，函数返回假； 有错则返回真。
# 和 lua_load 一样，这个函数仅加载代码块不运行。
# 此函数的返回值和 lua_load 相同。
# 也和 lua_load 一样，这个函数仅加载代码块不运行。
# 创建一张新的表，并把列表 l 中的函数注册进去。
# 它是用下列宏实现的：
# 数组 l 必须是一个数组，而不能是一个指针。
# 它以宏形式实现， 数组 l 必须是一个数组，而不能是一个指针。
# 这两种情况都会把最终的注册表中关联 tname 的值压栈。
# 返回新的状态机。 如果内存分配失败，则返回 NULL 。
# 打开指定状态机中的所有 Lua 标准库。
# 若 l 不为 NULL， 将结果的长度填入 *l 。
# 结束对缓存 B 的使用，将最终的字符串留在栈顶。
# 在栈上留下该模块的副本。
# 标准输入输出库中用到的标准文件句柄结构。
# 返回给定索引处值的类型名。
# 这个函数用于构建错误消息的前缀。
# 基础库提供了 Lua 核心函数。 如果你不将这个库包含在你的程序中， 你就需要小心检查程序是否需要自己提供其中一些特性的实现。
# 返回三个值（迭代函数、表 t 以及 0 ）， 如此，以下代码
# 加载一个代码块。
# Lua 不会对二进制代码块做健壮性检查。 恶意构造一个二进制块有可能把解释器弄崩溃。
# 能迭代表 t 中的所有键值对。
# 参见函数 next 中关于迭代过程中修改表的风险。
# 这个函数返回 table。
# 这个函数返回 table。
# 如果正在运行的协程可以让出，则返回真。
# 不在主线程中或不在一个无法让出的 C 函数中时，当前协程是可让出的。
# 这个路径被 require 在 C 加载器中做搜索时用到。
# 让宿主程序动态链接 C 库 libname 。
# 这个路径被 require 在 Lua 加载器中做搜索时用到。
# 保存有一些特殊模块的加载器 （参见 require）。
# 用于 require 控制如何加载模块的表。
# Lua 用四个查找器函数初始化这张表。
# 在指定 path 中搜索指定的 name 。
# 例如，如果路径是字符串
# 字符串库假定采用单字节字符编码。
# 数字编码没有必要跨平台。
# 数字编码没有必要跨平台。
# 如果在模式中定义了捕获，捕获到的若干值也会在两个索引之后返回。
# 会产生字符串：
# 下面这个例子会循环迭代字符串 s 中所有的单词， 并逐行打印：
# 任何情况下，模板中没有设定捕获都看成是捕获整个模板。
# 这里有一些用例：
# 返回字符串 s 的翻转串。
# 字符类：
# 字符类 用于表示一个字符集合。 下列组合可用于字符类：
# 模式条目：
# 模式条目 可以是
# 单个字符类匹配该类别中任意单个字符；
# 模式：
# 捕获：
# 格式串是由转换选项构成的序列。 这些转换选项列在后面：
# 返回一系列的值，可以让
# 这个函数假定 s 是一个合法的 UTF-8 字符串。
# 返回列表中的元素。 这个函数等价于
# 返回 x 的反余弦值（用弧度表示）。
# 返回 x 的反正弦值（用弧度表示）。
# 返回不小于 x 的最小整数值。
# 返回 x 的余弦（假定参数是弧度）。
# 将角 x 从弧度转换为角度。
# 返回 ex 的值 （e 为自然对数的底）。
# 返回不大于 x 的最大整数值。
# 浮点数 HUGE_VAL， 这个数比任何数字值都大。
# 最大值的整数。
# 最小值的整数。
# 返回 x 的整数部分和小数部分。 第二个结果一定是浮点数。
# 将角 x 从角度转换为弧度。
# 这个函数是对 C 提供的位随机数函数的封装。 对其统计属性不作担保。
# 返回 x 的正弦值（假定参数是弧度）。
# 返回 x 的正切值（假定参数是弧度）。
# 在出错的情况下，函数抛出错误而不是返回错误码。
# 在出错的情况下，函数抛出错误而不是返回错误码。
# 这个函数和系统有关，不是所有的平台都提供。
# 将写入的数据保存到 file 中。
# 在出错的情况下，函数抛出错误而不是返回错误码。
# 提供的格式有
# 格式 "l" 和 "L" 只能用于文本文件。
# 设置输出文件的缓冲模式。 有三种模式：
# 将参数的值逐个写入 file。 参数必须是字符串或数字。
# 这个库都通过表 os 实现。
# 返回程序使用的按秒计 CPU 时间的近似值。
# 返回给定 value 的元表。 若其没有元表则返回 nil 。
# 返回 udata。
# 返回指定函数第 n 个上值的唯一标识符（一个轻量用户数据）。
# 这个唯一标识符可以让程序检查两个不同的闭包是否共享了上值。 若 Lua 闭包之间共享的是同一个上值 （即指向一个外部局部变量），会返回相同的标识符。
# 选项有：
# 除 -i 与 -E 外所有的选项都按次序处理。 例如，这样调用
# 这张表是这样的：
# 更为通用。）
# 同样，Lua 版本更替还会改变预编译代码块的内部呈现方式； 在不同的 Lua 版本间，预编译代码块不兼容。
# 官方发布版的标准路径也可能随版本变化。
# 表处理库现在在读写其中的元素时会考虑元方法。
# Python mqtt daemon to talk with timebox mini
# Common HTML color names
# SVG Template
# Clay Config
# 没有将数据padding成固定格式，所以可能会比较慢
# 总的训练样本大概有50k首诗，最后效果还可以。
# Great success! ✨
# Redash ハンズオン資料は以下の環境を前提に動作確認をしています．
# なお，Redash のバージョンごとにハンズオン資料を用意しています．最新バージョン以外を使う場合は，以下のタグから参照できます．
# 以下のコマンドを実行し，Docker Compose で Redash を起動しましょう．
# 最初に Admin User と Organization Name を登録しましょう．以下にサンプルを載せておきます．登録が完了すると，Redash にログインできます．
# なお，Redash 環境の構築方法は Docker Compose 以外にもあります．興味のある方は，公式ドキュメントを読んでみましょう．
# 画面右上にある Settings アイコンをクリックし，「Settings」タブをクリックします．
# 日付フォーマットを以下の通りに変更します．
# ナビバーから「Create → Query」とクリックし，以下のクエリを入力しましょう．
# 入力したら「Execute」ボタンをクリックしてクエリを実行します．すると「国の一覧」が取得できます．
# クエリの実行ができたら，画面左上の「New Query」という部分をクリックし，クエリタイトルを **「国の一覧」** に変更します．忘れずに画面右側にある「Save」ボタンをクリックしましょう．
# さらに「Publish」ボタンをクリックします．Redash ではクエリを公開することで，他のユーザーに共有することができます．
# Redash ではクエリに対する「お気に入り登録」と「タグ登録」がサポートされています．
# なお `Counter` には「目標値」を設定する機能もあります．今回のデータソースではデータ件数に変化がありませんが，サンプルとして，作ってみましょう．先ほどのクエリを以下の通りに変更します．
# FROM city
# GROUP BY CountryCode
# 先ほどと同様に「+ New Visualization」タブをクリックし，以下の通りに設定をすると，円グラフを作ることができます．
# 次に棒グラフも作ってみましょう．設定は以下の通りです．
# これで棒グラフも作れました．
# 次にダッシュボードを作ってみましょう．
# Redash には Grouping Dashboards という機能があり，ダッシュボードタイトルにコロンを含めることで，同じグループのダッシュボードをまとめて管理することができます．詳しくは公式ドキュメントを読んでみましょう．
# 次にダッシュボードにグラフを配置していきます．
# 画面右下にあるメニューから「Add Widget」をクリックします．すると「Add Widget」というモーダルが表示されるため，以下の設定を繰り返し行いましょう．レイアウトは自由に変更することができます．
# ナビバーの「Queries」で `Unpublished` 状態になっているクエリがあったら，そのクエリを公開し，再度ダッシュボードにグラフを追加してみましょう．
# 最後に画面右上にある「Apply Changes」をクリックし，続けて「Publish」をクリックしましょう．クエリ同様にダッシュボードも他のユーザーに共有することができます．
# Redash ではクエリだけではなく，ダッシュボードに対しても「お気に入り登録」と「タグ登録」がサポートされています．
# 次はクエリにパラメータを付けてみましょう．
# SELECT *
# FROM city
# 今回は便利な「Dropdown List」を試しましょう．
# JPN
# USA
# Redash では，よく使うクエリ（もしくはクエリの一部）をクエリスニペットとして登録する機能があります．
# 画面右上にある Settings アイコンをクリックし，「Query Snippets」タブをクリックします．
# 次に「New Snippet」ボタンをクリックすると登録画面が表示されます．以下の設定をしたら「Save」ボタンを押しましょう．
# 新規クエリを作成し，以下のクエリを入力しましょう．クエリスニペットに登録した「Trigger」に部分一致すると候補として表示されるため `_` と入力するとクエリスニペットを呼び出すことができます．
# SELECT * FROM city _
# クエリスニペットにプレースホルダを設定することもできます．
# SELECT Code,
# Name,
# Population,
# CASE
# END AS Color
# FROM country
# UNION
# UNION
# ナビバーの「Queries」をクリックし，既に作ったクエリ **「国の一覧」** を開きましょう．
# 画面下にある「縦点」ボタン（Edit Visualization ボタンの右にある）を押すと，以下のメニューが表示されます．クエリ結果をダウンロードしてみましょう．
# 今回はハンズオンとして Redash を1人で使っていますが，一般的にはチームで使うことが多いと思います．
# チームで使っていると「メンバーが作ったクエリを少しカスタマイズしたい」と感じる場面があります．そのために Redash には「フォーク機能」があります．
# クエリを自由に変更できるため，以下のクエリを入力し，実行しましょう．表示するカラムを「国コード」と「名前」と「人口」にカスタマイズできました．なお，今回も「Format Query」を実行しておきましょう．
# Redash の機能は可視化だけではありません．特定の値が閾値を超えた場合にアラートを通知する機能があります．通知先は以下から選ぶことができます．
# Slack に Webhook 経由でアラートを通知してみましょう．今回は，自由に使える Slack アカウントがある前提で進めます．
# 画面右上にある Settings アイコンをクリックし，「Alert Destinations」タブにある「New Alert Destination」ボタンをクリックしましょう．次に「Slack」をクリックし，登録画面で以下を設定します．
# アラートを設定する前に，もう少し準備をしておく必要があります．
# 今回の例では，国の件数に変化はありませんが，定期的にクエリの実行をする機能です．アラートの設定をするクエリには「Refresh Schedule」の設定が必要です．
# 最後はアラートの設定です．ナビバーから「Create → Alert」をクリックし，「New Alert」の画面を開きます．以下のエラーが出る場合がありますが，問題ありません．
# 次に，Redash 管理者として Redash ユーザーを追加／無効化する運用手順を試してみましょう．
# まず，画面右上のメニューから「Users」をクリックし，次に「New User」ボタンをクリックします．なお，登録画面に以下のエラーが出る場合がありますが，問題ありません．
# 以下の通りに，Redash ユーザーを2個登録します．なお，2個目を登録する際は，タブの「Users」をクリックする必要があります．登録が終わったら，もう1度タブの「Users」をクリックし，ユーザー一覧で確認をしましょう．
# メンバーの退職など，Redash ユーザーを削除する場合はどうしたら良いのでしょう？
# List
# Comparing corpora
# Word clouds
# Combining with metadata
# Corpus analysis in R
# Latent Dirichlet Allocation
# UberspectをScala向け実装して、以下の機能拡張を行っています。
# ScalaVelocityEngineを使用します。
# 結果。
# Taro
# Java
# Scala
# Groovy
# Clojure
# Web?
# Final Results
# Run webpack to build the bundle
# Run a simple express server
# These methods
# Why?
# Why?
# Registering a library
# Eternal discomforting
# Present tense
# Poetic expressions
# A healthy state of mind
# Thank you for your suggestions!
# General Machine Learning
# Introductions and Guides to NLP
# Blogs and Newsletters
# 3t195yz9xCc
# VkXjvHfP3MM
# 7LnBvuzjpr4
# 1Ldzm7KGECI
# HL1UzIK-flA
# 3XR5mhXtpXw
# WsPfSXJaelk
# HPO_Eval 4 32 20 g
# HPO_Eval 4 32 20 g
# HPO_TestMe کیان 64
# HPO_TrainList
# Update your dependencies
# NULL
# NULL
# MIT
# Installation
# Usage
# Configuration
# Buka terminal dan tulis
# Berikut outputnya
# Cuekin aku Kak!
# Iya cuekin aku
# Gpp kok cuekin aku!
# That's right
# Ekspresi Subtitusi
# Halo Desty
# Buat kopi ukuran sedang
# Mesin sedang diservis
# Mesin sedang diservis
# Selamat siang
# Ida
# Benyamin
# Slamet
# Safi'i
# Ida
# Benyamin
# Slamet
# Safi'i
# Ida adalah seorang Penyanyi
# Benyamin adalah seorang Pelawak
# Slamet adalah seorang Pelukis
# Safi'i adalah seorang Penyair
# Halo! Selamat belajar Ruby
# Luas Segiempat adalah 20
# Halo dunia!
# Proc
# Proc pertama
# Proc kedua
# Proc
# Proc
# Halo Dunia!
# Outputnya tidak ada sama sekali
# Avanza melaju ke depan
# Avanza rem
# Avanza mundur ke belakang
# Avanza melaju ke depan
# Avanza rem
# Avanza mundur ke belakang
# TO
# TO
# TIGERBLOOD
# WINNING
# INTERSECTION
# UNION
# EXAMPLES
# In general,
# Copyright 2009, 2010 Kristopher Michael Kowal
# Where
# Where
# Where
# Where
# Where
# Where
# Where
# Where
# Where
# Where
# Where
# Where
# Where
# Thanks,
# Lisa
# Where `x` is a string
# To install these packages with
# Run tests with
# Server-side Components
# Client-side Components
# Hypothesis testing
# Sentiment
# NER
# ML Stacking
# Tensorflow tutorials
# Covariate shift
# WSDM 2019
# GOODBYE 2018
# Debug
# A collection of Call For Papers to never miss to speak anymore 🗣
# 关于屏幕方向的API参数如下图所示：
# LayaAir自动竖屏的示例代码如下：
# 手机竖屏状态下的LayaAir自动竖屏运行效果如下图所示：
# 手机横屏状态下的LayaAir自动竖屏运行效果如下图所示：
# Advanced benchmarking
# Sample usage
# Working with intersections
# There is a
# But see also
# PERSON
# STANDARD-GENERIC-FUNCTION
# FOO
# See more in the books !
# Lisp?*
# There is also a
# Yet another 2D API abstraction
# How fast?
# Licensed under either of
# This is the code for "A Guide to DeepMind's StarCraft AI Environment" by Siraj Raval on Youtube
# Other books
# Tableau
# SVG
# JavaScript
# Data Visualization Classes
# Blogs
# Color
# Misc
# In particular we probe
# OpenDrop
# And Dropbot
# Open Flexure Microscope
# G9S8ZWex
# Run
# Then
# Most of the procedure can be modified for a project by simply copying and
# This will setup LXC
# Install Procedure
# En user
# A salstack based redmine deployment
# SVN server deploymen based on salstack
# Installation
# You get
# Web view
# Does the opposite
# A place to store the data visualisations created as part of the PASTEUR4OA work
# Click me!
# Click me!
# Have fun!
# Updated map for Test
# Lisp syntax for vscode
# This scenario should give us
# 建立样本库是数据挖掘、人工智能研究不可缺少的基础工作。
# 推荐资料：
# 通过计算机把组成汉语文本的字串自动转换为词串的过程
# TF-IDF算法的步骤如下：
# 第三步，计算TF-IDF值，公式如下：
# 第四步，按照降序排序TF-IDF的值，取排在前面的前几个词。
# 参考：
# 对于该语料库的使用方式和应用场景也在多篇博文中提到：
# 参考：
# 简介：判断搜索结果与查询的相关性，是否符合搜索意图。
# 相关任务：基于互联网语料的信息检索。
# 简介：评测新闻话题跟踪及检测效果。
# 数据：完整版953条，数据格式“URL\t话题名称”。
# 相关任务：文本分类。
# 简介：评估文本分类结果的正确性。
# 数据：94条，数据格式“URL前缀\t对应类别标记”。
# 相关任务：文本分类。
# 数据：完整版1TB，迷你版10个页面数据。
# 相关任务：相关性排序，文本分类，新词发现，机器翻译，分词。
# 简介：包括对应互联网语料库内文档的链接关系列表。
# 相关任务：相关行排序，链接分析，反垃圾。
# 简介：互联网语料库中各页面的重要程度评级。
# 相关任务：相关性排序。
# 相关任务：相关行排序，用户兴趣挖掘，查询扩展，新词发现。
# 数据：完整版269GB。
# 数据：完整版635GB。
# 相关任务：基于内容的图片检索。
# 简介：基于互联网语料环境的高频词对应的词频、词性信息。
# 相关任务：中文词性标注，词频分析。
# 简介：基于互联网语料的字词搭配关系统计。
# 数据：完整版共18399496组，迷你版共100000组。
# 相关任务：中文输入法，文字到语音转化，语音识别。
# 1）话题检测，将新出现的文本内容聚类成候选话题。
# 3）根据相关话题生成新闻事件。
# 3）使用余弦相似度算法计算两篇文章间的相似度。
# 2）IWF与IDF比较：IWF模型的效果更平滑更优。
# 1）预处理：提取文本，分词，词性标注，停用词过滤，词频过滤。
# 中文词法分析
# THULAC：一个高效的中文词法分析工具包
# 包括中文分词、词性标注功能。已经提供C++、Java、Python版本。
# 中文文本分类
# 提供高效的中文文本特征提取、分类训练和测试功能。
# 知识表示学习
# 知识表示学习工具包
# 考虑实体描述的知识表示学习算法
# 词表示学习
# 跨语言词表示学习算法
# 主题增强的词表示学习算法
# 可解释的词表示学习算法
# 考虑字的词表示学习算法
# 网络表示学习
# 文本增强的网络表示学习算法
# Natural Language Toolkit
# 1 语料库的标注
# 2 语料库的索引
# 3 语料的智能化检索和显示
# 1 索引工具
# 2 标注工具
# 3 文本处理工具
# 4 数据驱动学习工具
# 标注模型
# 标注任务的组织和分解
# 标注质量控制机制
# 参考文献：《大数据语音语料库的社会标注技术》
# 这两种方法的区别如下：
# Repeat
# Add
# AIT Lisp interpreter in C
# Eudora in Ubuntu
# Installer
# Launches Eudora Mail under Wine
# Usage
# Description
# Options
# MAILTO-URI
# Attachments
# Environment Variables
# WINEPREFIX
# EUDORA_CONFIG
# Configuration files
# WINEPREFIX
# Exit Codes
# Examples
# Written by
# Licenses and Copyright
# Copyright © 2017-2018 Metosin Oy
# Jenkins Hands-On Session TYPO3 Camp Stuttgart 2016
# Preperation
# Vagrant Jenkins Box
# Vagrant Box exportieren
# Sketchnote
# Resources
# UserId Age Address
# 1 2105345   D       F
# 2 2085920   F       F
# 3 1976717   C       C
# 4  768535   A       E
# 5 1895117   D       F
# 6 1587807   J       E
# The date range is
# Value_per_ItemId
# Forest Logistic   Neural     Tree
# Note this extension has both
# To install CUDA
# To install cuDNN
# This limitation applies to
# MAPPCPD_ADMIN_USER"demo-pass"
# AND
# OR
# Yields 18,000+
# Yields 64,000+
# Mateusz Miotk
# Laptop ACER ASPIRE ONE 5820TG
# UWAGA!!!
# 1643     1
# 2    2  2236
# 3    3  4400
# 4    4  7126
# Statystyka
# Quote
# RNNs annotating?
# Mario RNN
# Stanford NLP
# Datasets
# NLP tasks
# Speculative NLP tasks
# NLP topics
# Syllabus
# NLP tasks
# NOTEBOOKS
# SOFTWARE
# MIT
# Installation
# Usage
# Inclusions and exclusions
# Grace period
# Hacking
# Help Wanted aka TODO
# License
# 视频事件
# 播放器事件
# 为了完善的浏览器兼容性，它应该是这样：
# 大多数移动端浏览器禁止了视频自动播放。
# A tool for creation, manipulation and maintenance of voice corpora
# Display help message
# Adds samples to current buffer
# Clears sample buffer
# Appends buffer to named buffer
# Drops named buffer
# Play samples of current buffer
# T
# Here is a blog post called
# If you're still
# Components for
# This is a CSS snippet
# This is a CSS snippet
# Passwords are not equal!
# 1-------
# 1-------
# Export complete
# Hands-on coding instruction
# Ruth Okoilu
# July 28, 2017
# The accuracy of our model is
# Fall 2014
# Hamilton Hall 150
# 一个优美英文诗歌的收集、翻译专辑。
# Sample Puppet Repositories
# Sample Puppet Repositories
# Recently, the
# We will use the
# Thanks!
# Jakub & Kamil,
# Clone repository
# Includes only core library
# Dependency parser
# Intent Extraction
# Bethke, Anna and
# Korat, Daniel and
# Yaccobi, Amit and
# Mamou, Jonathan and
# Guskin, Shira and
# Nittur Sridhar, Sharath and
# Keller, Andy and
# Pereg, Oren and
# Eirew, Alon and
# Tsabari, Sapir and
# Green, Yael and
# Kothapalli, Chinnikrishna and
# Eavani, Harini and
# Wasserblat, Moshe and
# Liu, Yinyin and
# Boudoukh, Guy and
# Zafrir, Ofir and
# Tribune DataViz Bookmarklets
# Installation
# Building the bookmarklets
# Author
# Tests
# Pods
# Options
# Snapcat
# Please note
# Installation
# Usage
# Contributing
# Credits
# 340 Pine Street, Sixth Floor
# San Francisco, CA 94104-3205
# USA
# PAULA
# JOHN
# PAULA
# Random Customer"`
# Thrifty Spender"`
# Thrifty Spender"`
# NIL
# Keep asking until the`
# If
# Print what is known,`
# 3`
# Why`
# Therefore,
# If
# Therefore,
# If
# If so, mild or serious?
# 3`
# Unfortunately, this won't`
# NIL
# NIL
# EVEN?
# ODD?
# REVERSE
# For example, the form
# As an example, the procedure
# 2 name!
# 2 name!
# T
# NIL
# Would this bea good idea?
# ONE-TWO
# T
# NIL
# In short, what's the point?
# BEING clauses omitted`
# If any of VARIABLES`
# NIL
# Which one?
# For example,
# NIL
# NIL
# NIL
# For example, if we say
# NIL
# NIL
# NIL
# How much is 32 + 60? 92
# Correct!
# How much is 91 + 19? 100
# Is it a ANIMAL? yes
# Is it a MAMMAL? yes
# I give up - what is it? bear
# Is it a ANIMAL? yes
# Is it a MAMMAL? no
# I give up - what is it? penguin
# Is it a ANIMAL? yes
# Is it a MAMMAL? yes
# Is it a BEAR? it
# AHA!
# IN WHAT WAY
# CAN YOU BE MORE SPECIFIC
# TELL ME MORE ABOUT YOUR FAMILY
# Shouldn't I be?
# WHY DO YOU SAY THAT JUST NOW?
# So?
# DO YOU WISH THAT YOU DID GET I?
# T
# NIL
# NIL
# NIL
# Is it still simpler?
# Is it more or less efficient?
# What is that object?
# If so, in what way?
# Start with states,`
# Start with states,`
# Start with paths,`
# Start with states,`
# X
# So, for example, given
# For example,
# Part III
# Tools and Techniques
# If you like, you can define
# M
# MIT
# Architecture
# API
# Schemas
# Number
# String
# Set
# 为大家推荐几本学习`Lisp`的书籍。
# 作为编程界两大圣经之一，麻省理工的本科教材。非常经典，该书以`Lisp`的方言`Scheme`做为代码示例。
# 通过阅读它可以开阔只学习了`C`，`Java`这样的命令式语言的同学的思路。
# 该书的作用是以下几本书中不可替代的，它是从如何学编程的角度讲的，以下的书是从如何学`Lisp`的角度讲的。
# 该书适合对`Lisp`有一定基础的同学，是迄今为止讲`Lisp`的书籍中最深的一本，至今无人超越。
# 该书作者是`Lisp`界的导师：保罗格雷勒姆于29岁时写的（大器早成啊）。
# 非常值得一看，是`Lisp`进阶的必读书籍。该书语言平实，示例经典，但是有一定难度。
# 该书在很大程度上展示了`Lisp`的威力和很多在使用过程中的注意事项。
# 这本书可以作为`Common Lisp`的入门教程，语言浅显易懂，示例也很到位，没有什么废话。
# 把`Lisp`的基本特性表述的很完整。该书于近些年成书，所以带有现代的气息。
# 非常不错，值得一看。该书只有英文版，可以免费在线阅读。
# 主要是讲`Common Lisp`的语法的。适合初学者阅读，书后的附录很有参考价值。
# 可快速阅读，该书只有英文版，没有 **_Successful Lisp_** 生动，但是书很薄，作为快速入门的途径不错。
# 该书的最大特点是废话多，前3章值得阅读。
# 最后几章的例子可以阅读。中间章节废话过多。
# 作为反例我把它列在这。该书把`Lisp`当作`Java`来写了，最后几章的示例中提供了很多面向对象的`Lisp`实例。
# 我个人认为`Lisp`不应该这么用，大家可以看看。
# Resources related to tagsets
# Finally
# EOF
# EOF
# Open Neural Network Exchange - ONNX
# Linear classifier
# OpenDNS Data Visualization Framework
# A live demo page can be found
# The binding can act as
# Useful tools
# Basic parameters
# Advanced parameters
# Basic parameters
# Advanced parameters
# Replace
# Replace
# Private machine learning progress
# Overview
# Network Prerequisites
# RTR
# Software Prerequisites
# Installation
# Running Open Overlay Router
# Features
# RTR mode
# Using Vagrant
# Using Dockers
# OpenWRT
# Android
# VPP
# NAT traversal
# Contact
# Using LISP tunneling
# Usage
# Paren matching
# What gets highlighted
# CSS class `function`
# CSS class `function known`
# CSS class `function symbol`
# CSS class `keyword`
# CSS class `keyword known`
# CSS class `symbol`
# CSS class `lambda-list`
# CSS class `number`
# CSS class `number integer`
# CSS class `number ratio`
# CSS class `number float`
# CSS class `number hex`
# CSS class `number binary`
# CSS class `variable known`
# CSS class `variable global`
# CSS class `variable constant`
# CSS class `nil`
# CSS class `comment`
# CSS class `string`
# CSS class `list`
# Why
# License
# The performance tests for OSIAM
# Minimum Hardware Requirements
# Recommended Hardware Requirements
# Software Requirements
# Or
# Sublime Build 3143
# Symbolic-Integration-Lisp
# The syntax is
# Query was executed successfully
# Run `gradle csvToExcelTask`
# Run `gradle csvDiffTask`
# Run `gradle xmlCleanTask`
# Run `gradle xmlUnitTask`
# Run `gradle readBlobTask`
# Run `gradle pullTask`
# Run `gradle pushTask`
# Installation
# Usage
# 1  government     825      85
# 2  state          787      85
# 3  people         612      85
# 4  one            544      85
# 5  new            324      85
# 6  york           151      85
# 7  publius         85      85
# 8  may            812      84
# 9  states         845      82
# 10 power          606      82
# 11 must           446      81
# 12 can            464      78
# 13 every          350      77
# 14 part           226      77
# 15 constitution   462      76
# 16 might          322      76
# 17 general        255      76
# 18 time           249      76
# 19 great          291      74
# 20 public         282      74
# Citation
# Contributing
# Acknowledgments
# Let's say we have a text to tag
# Let's Tag the text now!
# まず考えていることを言葉にします。
# わたしたちが作りたいショッピングカートってどういうもの？
# そんなショッピングカートを作るには、どうすればいいんだろう？
# Based on Polymer cheese app make OCR of scanned text
# Options for configure
# Preamble
# Definitions
# General Provisions
# Example 1
# Example 2
# Example 3
# Dialect
# Total              2342                   6300          10
# Dialect        Male      Female
# 1        DAB0, WBT0    ELC0
# 2        TAS1, WEW0    PAS0
# 3        JMP0, LNT0    PKT0
# 4        LLL0, TLS0    JLM0
# 5        BPM0, KLT0    NLP0
# 6        CMJ0, JDH0    MGD0
# 7        GRT0, NJM0    DHC0
# 8        JLN0, PAM0    MLD0
# 1           7        4       11
# 2          18        8       26
# 3          23        3       26
# 4          16       16       32
# 5          17       11       28
# 6           8        3       11
# 7          15        8       23
# 8           8        3       11
# Total       112       56      168
# File Type                     Description
# To get the alt depth per sample
# To parse and output genotype
# Also note you can use
# Get the version of the VCF file
# Get the column headers
# Get the sample names
# NORMAL,TUMOR
# NORMAL,TUMOR
# Info fields are referenced by
# Output
# Similar for base quality scores
# Filter out on sample values
# Or read depth for another
# 1       10665                   C       C               C       C
# 1       10694                   G       G
# 1       12783   G       G       G       G       G       G       G
# 1       15274   G       G       G       G       G       G       G
# Similarly for GoNL
# Total          130
# 请使用英语提issue
# For instance
# Welcome Star and PR
# Overview
# Workflow
# Installation
# Status
# What’s more
# Awesome CV
# At a command prompt, run
# Good luck!
# Introduction
# Table of Contents
# Courses
# Training and Testing
# AI
# Simple State Machine
# Walking,
# Idle
# State Machine
# Behavior Trees
# Utility Based AI
# Random Python scripts for data visualization
# Alternative Array
# MonadPlus Array
# MonadZero Array
# Alt Array
# Plus Array
# Bifunctor Either
# Bifoldable Either
# Bitraversable Either
# Functor List
# Foldable List
# Unfoldable List
# Traversable List
# Apply List
# Applicative List
# Bind List
# Monad List
# Alt List
# Plus List
# Alternative List
# MonadZero List
# MonadPlus List
# Extend List
# For example
# For example,
# For example,
# Get the length of a list
# For example,
# Functor Maybe
# Apply Maybe
# Applicative Maybe
# Alt Maybe
# Plus Maybe
# Alternative Maybe
# Bind Maybe
# Monad Maybe
# MonadZero Maybe
# Extend Maybe
# Invariant Maybe
# Monoid Unit
# Monoid String
# Foldable Array
# Foldable Maybe
# Foldable First
# Foldable Last
# Foldable Additive
# Foldable Dual
# Foldable Disj
# Foldable Conj
# Foldable Multiplicative
# Traversable Array
# Traversable Maybe
# Traversable First
# Traversable Last
# Traversable Additive
# Traversable Dual
# Traversable Conj
# Traversable Disj
# Traversable Multiplicative
# Semigroupoid Tuple
# Bifunctor Tuple
# Biapply Tuple
# Biapplicative Tuple
# Bifoldable Tuple
# Bitraversable Tuple
# Unfoldable Array
# Show Void
# Show Unit
# Eq Ordering
# Semigroup Ordering
# Show Ordering
# Applicative Array
# Apply Array
# Bind Array
# BooleanAlgebra Boolean
# BooleanAlgebra Unit
# Bounded Boolean
# Bounded Int
# Bounded Char
# Bounded Ordering
# Bounded Unit
# Category Function
# CommutativeRing Int
# CommutativeRing Number
# CommutativeRing Unit
# Eq Boolean
# Eq Int
# Eq Number
# Eq Char
# Eq String
# Eq Unit
# Eq Void
# EuclideanRing Int
# EuclideanRing Number
# EuclideanRing Unit
# Field Number
# Field Unit
# Functor Array
# HeytingAlgebra Boolean
# HeytingAlgebra Unit
# Monad Array
# Ord Boolean
# Ord Int
# Ord Number
# Ord String
# Ord Char
# Ord Unit
# Ord Void
# Ord Ordering
# Ring Int
# Ring Number
# Ring Unit
# Semigroup String
# Semigroup Unit
# Semigroup Void
# Semigroupoid Function
# Semiring Int
# Semiring Number
# Semiring Unit
# Show Boolean
# Show Int
# Show Number
# Show Char
# Show String
# Large Data Sets
# Friedman
# Proportional Hazards Model
# Data
# Angle Regression
# And dance upon the level shore?
# OWASP AppSec Pipeline
# Security testing tools
# HTTP proxies,
# Very good one with action items
# 10 Steps To Kickstart Your Web Application Security Career
# OWASP
# Button
# Button
# Button
# Button
# Button
# OK, incrementing grade by 5
# OK, incrementing grade by 20
# OK, incrementing grade by 10
# OK, incrementing grade by 10
# OK, incrementing grade by 20
# OK, incrementing grade by 10
# OK, incrementing grade by 10
# KO
# Or,
# Circle,
# Ellipse,
# G,
# Text,
# TSpan,
# TextPath,
# Path,
# Polygon,
# Polyline,
# Line,
# Rect,
# Use,
# Image,
# Symbol,
# Defs,
# LinearGradient,
# RadialGradient,
# Stop,
# ClipPath,
# Pattern,
# Mask,
# We go up and down,
# Masked text
# Happy computing!
# Host paperspace
# User paperspace
# Host paperspace
# User paperspace
# Работа с принтером
# Получение списка принтеров
# For each printer In printers Do
# Графическая персонализация
# Simply include
# Then have element
# Initialize in javascript
# Syntax
# CommonJS
# Destroy sticky element
# Clone this repository and run
# Paredit can be downloaded
# Table of Contents
# Installation
# Why
# Copyright © 2017 Roman Liutikov
# Stable version from CRAN
# Load `rcrossref`
# Citation count, using OpenURL
# 参数：
# 算路配置方法概览：
# BOOL avoidToll：设置是否避开收费道路
# BOOL avoidHighway：设置是否避开高速道路
# BOOL avoidTrafficJam：设置是否结合路况
# 回调NSError的错误码：
# 方法：
# 导航面板：
# 导航地图：
# 初始化过程如下：
# 路线规划成功后，在回调中获取用于导航的线路。
# 到达终点后会自动结束导航，导航过程中可以手动结束导航：
# 设置过程：
# 日夜切换模式TNKCarNaviDayNightMode：
# 日夜状态dayNightStatus：
# 设置过程：
# 用户可以设定默认导航面板、车道线、路口放大图是否显示。
# 注册过程为：
# 注册过程为：
# 注册过程为：
# 添加折线：
# 获取的导航数据可以用来添加导航面板控件，自定义导航面板。
# 使用`TNKCarNaviUIDelegate`协议获取数据。
# 使用`TNKCarNaviUIDelegate`协议获取数据。
# Abstract
# Demo
# Motivation
# Solution
# API
# Settings
# Event Handling
# Getting jQuery-Stage
# Building jQuery Stage
# See Also
# License
# Pedigree + GCTA analyses on Generation Scotland 20 data
# This is a fork of LISP-MAGICK, by Hans Bulfone, released under the BSD
# All materials licensed with
# Git Evangelism
# To do this, first
# Turing test, what’s that?
# Acknowledgements
# Install Python requirements
# And then run using
# Then run
# ToC
# Initial release
# F1-score
# John                 +-------+--------+
# 13,051 sentences
# 19,572 sentences
# 39,260 sentences
# NEWS STORY
# How to use it
# NuGet
# License
# The Teachers
# The Team
# Improvements for the AI's gameplay
# Villagers
# Military
# Ship
# None
# Practical-Machine-Learning-Project
# Background
# Data
# What you should submit
# Reproducibility
# For Firefox
# For Chrome
# For Internet Explorer
# Sentiment Analysis in Scala with Stanford CoreNLP
# Reading the Corpus
# Searching the Corpus
# 命令执行
# 复现没有回显。
# S2-005则是绕过官方的安全配置（禁止静态方法调用和类方法执行），再次造成漏洞。
# 会在age中得到相应的信息。
# POC
# But **what is awesome?**
# Thanks for being awesome!
# I am too busy in my work\
# I have no time for my haters\
# I wanna shine in the sky\
# I wanna appear in theatres\
# For those who don’t like me\
# Can sit on the side\
# Because I am going to win\
# By a landslide\
# Those who don’t care about me\
# I say them namaste\
# And close my door
# I am going ahead in life\
# I don’t live in past\
# I have plans for future\
# And time is moving fast\
# Can’t scare me of my future\
# As my wrongs are my tutor\
# The things of past\
# Don’t affect my snore\
# I say them namaste\
# And close my door
# Norvig and Pitman's
# Overview
# Quick setup instructions
# Contribs
# License
# Contact
# 标签（空格分隔）： python3
# I wish I had thought of a rhyme
# Before I ran all out of time!
# I'll sit here instead,
# A cloud on my head
# 它的诗歌形式描述
# 8 A
# 5 B
# 5 B
# 8 A
# 以下是英文原文
# I wish I had thought of a rhyme
# Before I ran all out of time!
# I'll sit here instead,
# A cloud on my head
# 8 A
# 8 A
# 5 B
# 5 B
# 8 A
# Jen sits quietly,
# 5 *
# 7 *
# 5 *
# 0 A
# 0 B
# 0 A
# 0 B
# 0 B
# Teach us, Sprite or Bird,
# I have never heard
# Praise of love or wine
# How to tackle this assignment
# As I awoke one morning, when all good things are born
# What are your best-practices?
# Draft
# Only if it's water-proof!
# Get involved!
# 1-------
# 1-------
# 2-------
# Your Name Here
# Your Name Here
# 1	one
# 3	hello dolly
# 7	end
# Install using fastlane
# Matej Sychra
# Felix Krause
# QRCode for JavaScript
# DENSO WAVE INCORPORATED
# Requested page
# HTTP Response
# Requested page
# HTTP Response
# Requested page
# HTTP response
# Using UTF-8 encoding
# Loading Database Dump
# Dependencies
# 日本語技術書のコーパス。
# 日本語の再配布が可能な技術書を集めたものです。
# 商用利用できないライセンスを含みます。
# 開発中のルールをコーパスでテストする方法。
# パターンでの絞り込みもできます。
# このコーパスは次の文書を含んでいます。
# それぞれの文書のライセンスに基づき再配布されています。
# MIT © azu
# No unit test coverage for node
# Intern
# Tunnel started
# No unit test coverage for node
# Leadfoot’s
# Tunnel started
# No unit test coverage for node
# Tunnel started
# Total coverage
# Tunnel started
# Total coverage
# Happy testing!
# DT-cut
# Lisp training
# MIT
# 两个Table 相加的时候会调用我
# 两个Table 相加的时候会调用我
# Lua Post 方式获取提交的name参数的值：
# The man name is Tinywan
# The man name is Phalcon
# OpenResty Fan Tinywan Anonymous
# OK
# OK
# OK
# Kernel IP routing table
# Destination     Gateway         Genmask         Flags Metric Ref    Use Iface
# Pretty neat, eh?
# Boost Genetics
# Running the application
# Field usage
# 0,
# Locally
# CDN
# Getting Started
# Victims may be a
# You can clone it from
# The Iago feeder creates
# The Iago server creates
# MIT licens
# Assignment 1
# Setting up accounts
# Working with a partner
# Grading
# Submission details
# Can I use some different data?
# Grading
# Submission details
# Final project
# Deadlines
# Assessment
# Final Deliverables
# Getting started
# Dataviz in R
# Brown bag lunch, June 18, 2015
# ESS, Team F
# Case Statistical Yearbook
# Content
# Population data from FAOSTAT
# Population data from FAOSTAT
# Share of rural population
# Share of rural population
# Share of rural population
# Share of rural population
# Exporting for post-processing
# Interactive graphics
# Interactive maps
# Interactive maps
# Interactive time-series
# R for dataviz
# As discussed in our
# On Windows, you can find
# Let's get started!
# Brain with Reinforcement
# We would like to thank
# The `Ball3DAgent` in the
# When calling `step` or
# You can
# The
# Your code is expected to return
# Consider our
# See
# You can also compare the
# In this tutorial we used the
# There is no data folder
# Morphology in the Romanian Language
# Code Formatters
# Displaying 11 of 11 matches
# Displaying 75 of 75 matches
# And what if we raise the order?
# 23,687,560,947 processor cycles
# 229,392 bytes consed
# 33,396,336 processor cycles
# 613,568 bytes consed
# A 1000x speed increase!
# Official Resources
# External Resources
# Community
# Podcasts
# Official Examples
# Tutorials
# Development Tools
# Syntax Highlighting
# Snippets
# Autocomplete
# Libraries & Plugins
# Routing
# State Management
# Validation
# UI Components
# Examples
# Boilerplates
# Scaffolding
# Integrations
# Open Source
# Interactive Experiences
# Enterprise Usage
# Official Resources
# Official Guide
# API Reference
# GitHub Repo
# Release Notes
# External Resources
# Community
# Twitter
# Gitter Chat Room
# Official Forum
# Podcasts
# Official Examples
# Basic Examples
# CoffeeScript Version
# Tutorials
# Development Tools
# Syntax Highlighting
# Sublime Text
# Atom
# Vim
# Visual Studio Code
# Brackets
# Emacs
# Snippets
# Autocomplete
# Libraries & Plugins
# Routing
# Vue page
# Vue Lanes
# Vue route
# Boris Okunskiy
# PageKit
# State Management
# Validation
# Vue validator
# UI Components
# VueStrap
# VueBoot
# Vue Tag Editor Component
# Vue Crop
# Vue Typeahead
# Typed select component
# SVG icons
# Extra Vuestrap components
# VueStrap Base Components
# Vue YouTube Embed
# Vue datepicker
# Vue-progressbar
# Famous-Vue
# Vue-slide
# Vue-quill
# Quill
# Vue-calendar
# Vue Material Components
# Examples
# Node Webkit + Vue example
# Vue Samples
# Electron + Vue example
# Boris Okunskiy
# Raj Abishek
# Vue Mini Shop
# BosNaufal
# Vue SoundCloud
# Boilerplates
# Scaffolding
# Vue generator
# VENM stack yeoman generator
# Grail Yeoman Generator
# VuePack
# VueWebgulp
# Vuetober
# Brunch with Vue
# Vue-Django
# Integrations
# Vue for Meteor
# Socketize Backend
# Vue-Meteor-Data
# Vue Proerty Decorator
# Vue placeholder directives
# Vue once directive
# Vue Modified Directive
# A collection of filters
# Talks
# Vue unit tests
# Open Source
# PageKit
# Python China
# Todolist
# Dashboard framework
# FilterBlend
# Koel
# Selection Translator
# SwitchHosts
# RSS Reader
# Gokotta
# Coffeebreak
# Laravel Spark
# Vice Video
# Formlets
# Laracasts
# CUUSOO
# 稀土掘金
# Prague Airport
# Expressionery
# BUYIT
# Workswell Australia
# Portfolio Site
# Grammarly
# Laravist
# Atiiv
# Statamic
# Embalses!
# TravelMap
# Proper Cloth Shirt Builder
# Custom shirt builder
# CheckIt
# Reddit News
# 小桃酱
# Interactive Experiences
# Facebook NewsFeed
# YouTube AdBlitz 2016
# Blood, Sweat and Tools
# Omnisense Experience
# Being the Bear
# Heineken Star Experience
# Digital For All
# NOIZE original
# Enterprise Usage
# Alibaba
# Baidu
# Sina Weibo
# Xiaomi
# Optimizely
# Expedia
# UCWeb
# Line
# Nintendo
# Celtra
# Sainsbury's
# AREX
# Tuniu mp
# License
# 参考吴翰清的《白帽子讲Web安全》一书。
# 执行以下命令启动s2-001测试环境
# 执行任意命令POC（无回显，空格用`@`代替）：
# 期待大佬研究出有回显的POC。
# 2 0xf7fa35a0
# 8 0xf7fa33dc
# 9 0xffffd360
# 50 0xffffd3ec
# 53 0xffffd57f
# 55 0xffffd5a0
# 56 0xffffdb5c
# 57 0xffffdb73
# 58 0xffffdb82
# 59 0xffffdb93
# 60 0xffffdba8
# 61 0xffffdbb3
# 62 0xffffdbc8
# 63 0xffffdbdc
# 64 0xffffdbea
# 65 0xffffdbf5
# 66 0xffffdc1b
# 67 0xffffdc2c
# 68 0xffffdc36
# Run calibration target service
# Edit the launch file
# Run calibration target service
# Edit the launch file
# Edit the launch file
# Start roscore and sync times
# Arguments
# Keys
# Calibrate z axis
# Calibrate y axis
# Calibrate x axis
# Button Mapings
# Button Mapings
# Y - Stop Manipulation Pipeline
# Back - Go home
# Xbox Button - AUTO
# MOVEMENT
# TESTING
# TRAJECTORY HANDLING
# DEBUGGING
# EXPERIENCE PLANNING
# Start fake controllers
# Rviz Visualizer
# Load meshes
# See what is connected
# See what is connected
# See what is connected
# Change device ID
# Test camera view
# Visualizer
# Gelsight
# 0 Do nothing
# 2 Go home
# 3 Insertion task
# 4 Gelsight touch control
# 10 Automated Insertion Test
# 41 Get SRDF pose
# Material
# Add a single word to the corpus
# What the point of this method?
# Practical Machine Learning Project
# Have fun!
# Further, for Task 2 one
# March 19, 2019
# April 16, 2017
# Team Wit
# InterpretString
# It is being developed by
# 1、下载本工具
# 3、安装composer包依赖
# 4、开始编译成 `sql` 文件
# Installation & Configuration
# You are done
# Allocating Memory
# Trying strategy bysize
# Allocating Memory
# Trying strategy bysize
# Trying strategy bottom
# Trying strategy top
# Trying strategy tops
# Trying strategy bottle
# Trying strategy bottles
# Trying strategy xXx
# Trying strategy shuffle
# Cloud Services
# Enjoy the generated poems!
# CSS3
# George N B-PER
# Washington N I-PER
# Washington N B-LOC
# Therefore, you can use all
# False,
# Done!
# This scenario should give us
# Template message
# TP=4526, TN=198461, FP=2841, FN=3020
# Precision=0.6143613410323929, recall=0.5997879670554217, F1=0.6069866923735284
